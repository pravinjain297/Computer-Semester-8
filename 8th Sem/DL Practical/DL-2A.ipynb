# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import * 
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Load the OCR letter recognition dataset, Link
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data'
# dataset = pd.read_csv(url, header=None)

# %%
# Load the OCR letter recognition dataset
url = 'letter-recognition.data'
df = pd.read_csv(url, header=None)

# %%
# Split the dataset into features and labels
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# %%
# Encode the labels
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print(X_train)
# Out:
# [[ 3  8  4 ...  8  6  8]
#  [ 5 11  7 ...  7  8  8]
#  [ 6 10  9 ...  8  6  7]
#  ...
#  [ 7  9  6 ...  8  3  4]
#  [ 3  1  4 ...  5  2  8]
#  [ 4  8  5 ... 10  3  5]]

# %%
X_train = X_train / 15.0
X_test = X_test / 15.0

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(16,)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(26, activation='softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics =['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=12)
# Out:
# Epoch 1/50
# 1334/1334 [==============================] - 4s 2ms/step - loss: 2.6498 - accuracy: 0.2104 - val_loss: 1.7889 - val_accuracy: 0.5515
# Epoch 2/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.8800 - accuracy: 0.4143 - val_loss: 1.3735 - val_accuracy: 0.6215
# Epoch 3/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.6377 - accuracy: 0.4796 - val_loss: 1.2352 - val_accuracy: 0.6560
# Epoch 4/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.4980 - accuracy: 0.5271 - val_loss: 1.1180 - val_accuracy: 0.6870
# Epoch 5/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.3991 - accuracy: 0.5565 - val_loss: 1.0668 - val_accuracy: 0.6865
# Epoch 6/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.3523 - accuracy: 0.5694 - val_loss: 1.0043 - val_accuracy: 0.7128
# Epoch 7/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.3006 - accuracy: 0.5839 - val_loss: 0.9571 - val_accuracy: 0.7197
# Epoch 8/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.2564 - accuracy: 0.5941 - val_loss: 0.9120 - val_accuracy: 0.7258
# Epoch 9/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.2238 - accuracy: 0.6129 - val_loss: 0.8984 - val_accuracy: 0.7327
# Epoch 10/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.1964 - accuracy: 0.6209 - val_loss: 0.8559 - val_accuracy: 0.7365
# Epoch 11/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.1791 - accuracy: 0.6212 - val_loss: 0.8416 - val_accuracy: 0.7515
# Epoch 12/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.1512 - accuracy: 0.6337 - val_loss: 0.8067 - val_accuracy: 0.7588
# Epoch 13/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.1288 - accuracy: 0.6410 - val_loss: 0.7878 - val_accuracy: 0.7632
# Epoch 14/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.1105 - accuracy: 0.6475 - val_loss: 0.7912 - val_accuracy: 0.7613
# Epoch 15/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.0909 - accuracy: 0.6513 - val_loss: 0.7549 - val_accuracy: 0.7703
# Epoch 16/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.0828 - accuracy: 0.6549 - val_loss: 0.7428 - val_accuracy: 0.7650
# Epoch 17/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.0626 - accuracy: 0.6580 - val_loss: 0.7473 - val_accuracy: 0.7742
# Epoch 18/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.0513 - accuracy: 0.6674 - val_loss: 0.7240 - val_accuracy: 0.7828
# Epoch 19/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.0492 - accuracy: 0.6677 - val_loss: 0.7404 - val_accuracy: 0.7780
# Epoch 20/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 1.0461 - accuracy: 0.6696 - val_loss: 0.7042 - val_accuracy: 0.7910
# Epoch 21/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0228 - accuracy: 0.6744 - val_loss: 0.6833 - val_accuracy: 0.8015
# Epoch 22/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 1.0223 - accuracy: 0.6769 - val_loss: 0.6826 - val_accuracy: 0.7912
# Epoch 23/50
# 1334/1334 [==============================] - 4s 3ms/step - loss: 1.0063 - accuracy: 0.6811 - val_loss: 0.6766 - val_accuracy: 0.7965
# Epoch 24/50
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.9982 - accuracy: 0.6796 - val_loss: 0.6803 - val_accuracy: 0.7915
# Epoch 25/50
# 1334/1334 [==============================] - 4s 3ms/step - loss: 0.9939 - accuracy: 0.6849 - val_loss: 0.6480 - val_accuracy: 0.8060
# Epoch 26/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9875 - accuracy: 0.6881 - val_loss: 0.6355 - val_accuracy: 0.8090
# Epoch 27/50
# 1334/1334 [==============================] - 2s 1ms/step - loss: 0.9858 - accuracy: 0.6829 - val_loss: 0.6454 - val_accuracy: 0.7983
# Epoch 28/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9809 - accuracy: 0.6891 - val_loss: 0.6424 - val_accuracy: 0.8050
# Epoch 29/50
# 1334/1334 [==============================] - 2s 1ms/step - loss: 0.9783 - accuracy: 0.6882 - val_loss: 0.6372 - val_accuracy: 0.8115
# Epoch 30/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9744 - accuracy: 0.6888 - val_loss: 0.6349 - val_accuracy: 0.8083
# Epoch 31/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9561 - accuracy: 0.6928 - val_loss: 0.6254 - val_accuracy: 0.8015
# Epoch 32/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9520 - accuracy: 0.6968 - val_loss: 0.6176 - val_accuracy: 0.8123
# Epoch 33/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9510 - accuracy: 0.6942 - val_loss: 0.6247 - val_accuracy: 0.8085
# Epoch 34/50
# 1334/1334 [==============================] - 3s 2ms/step - loss: 0.9411 - accuracy: 0.7040 - val_loss: 0.6163 - val_accuracy: 0.8095
# Epoch 35/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9395 - accuracy: 0.7023 - val_loss: 0.6213 - val_accuracy: 0.8065
# Epoch 36/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9500 - accuracy: 0.6993 - val_loss: 0.6050 - val_accuracy: 0.8255
# Epoch 37/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9433 - accuracy: 0.7031 - val_loss: 0.5996 - val_accuracy: 0.8173
# Epoch 38/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9375 - accuracy: 0.7003 - val_loss: 0.5973 - val_accuracy: 0.8173
# Epoch 39/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9209 - accuracy: 0.7034 - val_loss: 0.5827 - val_accuracy: 0.8267
# Epoch 40/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9330 - accuracy: 0.7034 - val_loss: 0.5897 - val_accuracy: 0.8242
# Epoch 41/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9257 - accuracy: 0.7057 - val_loss: 0.5827 - val_accuracy: 0.8183
# Epoch 42/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9177 - accuracy: 0.7042 - val_loss: 0.5770 - val_accuracy: 0.8230
# Epoch 43/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9440 - accuracy: 0.7014 - val_loss: 0.5822 - val_accuracy: 0.8242
# Epoch 44/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9068 - accuracy: 0.7109 - val_loss: 0.5697 - val_accuracy: 0.8250
# Epoch 45/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9171 - accuracy: 0.7072 - val_loss: 0.5718 - val_accuracy: 0.8338
# Epoch 46/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9081 - accuracy: 0.7106 - val_loss: 0.5637 - val_accuracy: 0.8322
# Epoch 47/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9266 - accuracy: 0.7053 - val_loss: 0.5668 - val_accuracy: 0.8350
# Epoch 48/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9051 - accuracy: 0.7124 - val_loss: 0.5750 - val_accuracy: 0.8292
# Epoch 49/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.8974 - accuracy: 0.7134 - val_loss: 0.5649 - val_accuracy: 0.8315
# Epoch 50/50
# 1334/1334 [==============================] - 2s 2ms/step - loss: 0.9035 - accuracy: 0.7109 - val_loss: 0.5523 - val_accuracy: 0.8350

# %%
# Plot training and validation accuracy
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training and validation loss
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test accuracy:", accuracy)
print("Test loss:", loss)
# Out:
# 125/125 [==============================] - 0s 2ms/step - loss: 0.5523 - accuracy: 0.8350
# Test accuracy: 0.8349999785423279
# Test loss: 0.5522528290748596

# %%
model.save('ocr_model.h5')
# Save the trained model

# %%
from tensorflow.keras.models import load_model
model = load_model('ocr_model.h5')
# Load the trained model

# %%
sample_records = X_test[:1000]
# Select a few records for classification

# %%
# Perform classification
predictions = model.predict(sample_records)

# %%
predicted_labels = np.argmax(predictions, axis=1)

# %%
predicted_letters = label_encoder.inverse_transform(predicted_labels)
actual_letters = label_encoder.inverse_transform(y_test)

# %%
# Print the predicted labels and corresponding actual labels
print("Predicted Labels\tActual Labels")
for i in range(len(predicted_letters)):
    print(f"{predicted_letters[i]}\t\t\t{actual_letters[i]}")
# Out:
# Predicted Labels	Actual Labels
# D			D
# D			D
# V			V
# B			B
# H			H
# N			N
# R			E
# Q			Q
# E			R
# N			N
# Q			Q
# O			O
# N			N
# B			D
# F			I
# M			M
# U			U
# S			S
# O			O
# A			A
# X			X
# A			A
# K			K
# S			S
# O			O
# V			V
# Y			Y
# J			J
# D			D
# V			V
# H			D
# V			V
# K			K
# Y			F
# N			N
# I			I
# G			G
# T			T
# H			H
# K			K
# J			J
# O			O
# M			M
# T			T
# B			B
# Q			Q
# Z			Z
# C			C
# D			D
# X			X
# E			C
# G			G
# Q			Q
# F			F
# N			N
# Y			Y
# Z			Z
# K			K
# S			C
# K			T
# M			M
# V			V
# G			G
# R			M
# D			D
# T			T
# H			H
# P			P
# N			N
# C			C
# O			O
# X			X
# X			X
# Q			Q
# V			V
# F			P
# V			V
# G			G
# W			W
# O			H
# P			P
# O			O
# I			I
# G			G
# X			X
# Y			X
# Y			P
# W			W
# O			Q
# D			D
# B			N
# Q			Q
# T			T
# T			T
# V			V
# Y			Y
# T			T
# V			V
# J			J
# M			U
# D			D
# L			L
# M			M
# Y			Y
# E			E
# M			M
# A			A
# Y			Y
# K			K
# Y			Y
# U			U
# U			U
# U			U
# E			C
# G			Q
# I			I
# A			A
# E			E
# B			D
# T			T
# B			P
# Q			Q
# Z			Z
# G			G
# X			X
# G			G
# F			F
# M			M
# S			S
# E			E
# E			E
# K			K
# Z			Z
# X			X
# D			O
# E			E
# U			U
# I			I
# R			R
# O			O
# M			M
# J			J
# F			F
# K			K
# M			M
# N			N
# G			T
# D			D
# H			H
# R			R
# L			L
# Z			Z
# F			F
# V			V
# W			W
# E			E
# T			T
# W			W
# Y			Y
# Q			Q
# L			L
# F			F
# O			O
# D			D
# K			K
# S			I
# T			X
# P			P
# H			H
# Q			Z
# D			H
# W			W
# F			F
# B			B
# R			R
# O			O
# B			B
# S			Z
# N			N
# W			W
# Z			Z
# W			W
# V			V
# B			S
# Y			Y
# H			H
# Q			O
# Y			Y
# V			V
# S			S
# W			W
# B			B
# P			P
# D			D
# Z			Z
# O			O
# X			X
# F			P
# B			B
# S			S
# T			T
# X			X
# J			J
# B			B
# Y			Y
# S			I
# Z			Z
# Z			Z
# P			P
# E			E
# O			H
# Q			Q
# F			I
# A			A
# H			H
# P			P
# E			E
# U			U
# K			K
# P			P
# M			M
# C			C
# X			Y
# J			J
# W			W
# M			M
# G			G
# J			J
# O			O
# K			H
# P			P
# L			L
# W			W
# A			A
# C			C
# C			C
# C			C
# O			O
# J			J
# Y			Y
# P			P
# Y			Y
# A			A
# R			R
# Z			Z
# J			J
# I			I
# G			G
# G			G
# I			I
# N			K
# G			M
# R			R
# T			T
# S			D
# E			E
# D			D
# L			L
# W			W
# G			P
# L			L
# U			U
# O			O
# T			T
# A			A
# V			V
# D			D
# U			U
# X			X
# X			X
# G			G
# C			C
# B			F
# Z			Z
# W			W
# T			T
# V			V
# T			T
# P			P
# M			M
# S			S
# U			U
# X			F
# Q			Q
# B			B
# Q			G
# H			K
# L			L
# F			F
# E			E
# R			R
# P			P
# R			R
# W			W
# I			I
# Y			Y
# Y			Y
# B			B
# C			C
# T			T
# M			M
# M			M
# D			N
# B			B
# R			R
# Z			Z
# G			G
# D			D
# R			R
# I			I
# Y			Y
# F			P
# M			M
# A			A
# B			B
# M			M
# R			F
# G			G
# Q			Q
# Z			Z
# P			P
# O			O
# Q			Q
# P			P
# G			G
# N			N
# O			O
# T			T
# G			G
# S			S
# V			V
# Z			Z
# A			A
# P			P
# J			J
# O			O
# N			N
# Q			Q
# K			K
# X			X
# S			E
# F			P
# J			J
# N			N
# X			X
# X			X
# V			V
# Q			Q
# Y			H
# A			A
# T			T
# S			S
# W			W
# M			M
# P			P
# Y			Y
# M			U
# S			Z
# R			R
# B			B
# A			A
# Y			Y
# F			F
# X			F
# B			D
# A			A
# N			N
# A			A
# N			H
# Q			Q
# P			P
# Z			Z
# R			R
# B			D
# W			W
# R			O
# Q			Q
# K			K
# N			N
# W			W
# P			P
# W			W
# S			S
# K			K
# S			S
# I			J
# E			E
# S			S
# V			V
# S			S
# O			O
# V			V
# Q			T
# X			X
# Q			Q
# W			W
# I			I
# Z			Z
# B			D
# F			F
# P			P
# M			R
# P			P
# C			C
# D			D
# J			J
# G			L
# I			I
# D			H
# X			X
# B			D
# U			U
# G			G
# O			O
# K			K
# K			K
# K			K
# P			P
# P			P
# G			G
# T			T
# F			F
# B			B
# Y			Y
# V			Y
# I			I
# H			H
# E			E
# S			S
# Y			Y
# B			S
# T			T
# Q			Q
# L			L
# R			M
# I			I
# Z			Z
# F			F
# A			A
# J			J
# B			V
# G			G
# U			U
# S			Z
# H			H
# O			O
# D			N
# J			J
# E			T
# O			O
# H			H
# V			V
# F			F
# L			L
# W			W
# M			M
# Y			Y
# J			J
# P			P
# W			W
# E			E
# A			A
# B			B
# W			N
# O			O
# Q			Q
# Y			Y
# Q			Q
# F			F
# A			A
# A			A
# Q			Q
# Z			Z
# E			E
# H			H
# N			N
# E			E
# A			A
# R			R
# G			C
# Z			Z
# Q			Q
# V			V
# O			O
# F			T
# K			K
# M			M
# R			R
# Y			Y
# X			X
# X			X
# J			J
# X			X
# Q			Q
# T			T
# S			S
# A			A
# X			X
# G			G
# T			T
# N			N
# B			S
# Y			Y
# P			P
# A			A
# S			I
# T			T
# Q			X
# X			X
# C			C
# O			O
# B			B
# G			G
# R			W
# D			D
# K			K
# O			U
# S			S
# W			O
# Z			Z
# Q			L
# D			N
# R			R
# V			V
# A			A
# K			L
# B			D
# W			W
# I			I
# B			O
# K			C
# W			W
# A			A
# Y			Y
# Q			Q
# L			L
# G			Q
# K			K
# J			J
# E			E
# B			B
# P			P
# J			J
# R			R
# X			X
# N			N
# A			A
# G			G
# C			C
# D			T
# L			L
# S			S
# A			A
# N			N
# G			K
# V			V
# B			G
# A			A
# D			D
# H			H
# Y			Y
# Z			Z
# Q			Q
# C			C
# U			U
# Q			Q
# Z			Z
# M			M
# D			D
# B			B
# L			L
# B			R
# Q			Q
# D			D
# F			F
# W			W
# Q			Q
# M			M
# G			G
# S			Z
# B			B
# U			U
# N			N
# K			K
# V			P
# A			A
# W			U
# P			F
# T			T
# X			X
# L			L
# U			U
# Y			Y
# P			P
# Y			Y
# B			R
# E			S
# K			K
# G			E
# Q			Q
# F			F
# W			W
# V			P
# P			P
# M			M
# N			N
# Z			Z
# G			G
# R			K
# O			O
# W			W
# I			I
# F			C
# E			E
# U			U
# R			R
# F			I
# Y			Y
# X			S
# W			V
# R			R
# C			C
# Q			Q
# C			C
# S			J
# Y			Y
# S			S
# K			K
# G			L
# X			X
# T			T
# I			I
# D			F
# W			W
# A			A
# Q			D
# K			K
# A			A
# Z			Z
# M			M
# G			G
# G			G
# W			W
# W			W
# Z			Z
# W			W
# T			T
# O			O
# R			R
# T			T
# N			N
# S			S
# Q			Q
# J			J
# Q			Q
# M			M
# O			O
# A			A
# N			N
# Z			Z
# B			D
# T			T
# J			I
# U			U
# A			A
# O			N
# G			G
# O			P
# L			L
# S			F
# R			R
# C			C
# P			P
# Y			Y
# Y			Y
# T			T
# A			A
# S			Y
# T			T
# Q			E
# T			T
# O			O
# S			S
# N			N
# O			O
# I			I
# O			O
# U			U
# N			N
# Z			Z
# J			J
# C			C
# N			H
# S			S
# G			L
# H			H
# E			C
# Q			Q
# F			F
# B			B
# W			O
# I			I
# K			K
# O			O
# B			R
# E			E
# L			L
# M			M
# L			L
# X			T
# E			E
# U			U
# V			W
# E			F
# D			D
# N			N
# V			V
# M			M
# I			I
# X			K
# L			L
# Y			Y
# Q			Q
# F			F
# U			U
# J			J
# V			V
# M			M
# P			P
# W			W
# L			L
# A			A
# L			L
# B			B
# Y			Y
# I			I
# D			D
# R			R
# T			T
# Q			Q
# B			B
# O			U
# M			M
# O			O
# I			I
# U			U
# U			U
# X			K
# S			J
# I			I
# W			W
# Z			Z
# Z			Z
# P			P
# A			A
# Z			Z
# P			P
# V			V
# O			G
# B			B
# G			G
# O			O
# V			V
# D			D
# Z			Z
# Y			Y
# P			P
# Q			Q
# A			A
# E			E
# W			W
# D			D
# J			J
# I			I
# J			J
# X			X
# F			S
# Z			Z
# G			G
# X			T
# U			U
# K			K
# G			G
# I			I
# N			N
# S			I
# W			W
# I			I
# I			I
# P			P
# B			B
# O			O
# H			H
# F			D
# O			O
# N			N
# Z			S
# D			D
# S			S
# M			M
# O			O
# O			N
# Y			Y
# S			X
# Q			Q
# M			M
# R			R
# G			G
# X			G
# A			A
# R			K
# U			U
# U			O
# B			P
# G			C
# V			V
# D			D
# B			B
# A			A
# E			E
# B			R
# T			T
# I			I
# S			Z
# N			N
# O			O
# B			B
# C			C
# G			G
# J			J
# E			E
# N			N
# J			J
# Q			H
# P			P
# O			O
# O			O
# B			B
# X			X
# D			D
# S			S
# O			O
# O			O
# G			G
# B			B
# R			H
# C			C
# A			A
# W			W
# P			P
# I			I
# N			N
# M			M
# G			G
# M			N
# A			A
# J			H
# K			K
# N			N
# M			M
# F			F
# W			W
# A			A
# S			S
# E			E
# G			T
# J			J
# H			H
# N			N
# K			K
# W			W
# W			W
# U			U
# G			L
# Z			Z
# Z			Z
# Z			Z
# G			G
# T			T
# J			J
# V			V
# W			W
# L			L
# M			M
# U			U
# W			W
# G			G
# A			A
# T			T
# J			J
# C			C
# G			G
# D			D
# Y			Y
# Y			Y
# X			X
# N			N
# Y			Y
# S			S
# K			K
# U			U
# M			W
# R			R
# R			B
# T			T
# R			R
# H			H
# R			R
# M			M
# O			O
# W			W
# X			X
# R			R
# X			X
# N			N
# H			H
# C			C
# G			C
# J			J
# V			V
# V			V
# I			I
# R			R
# W			W
# X			H
# N			N
# E			E
# U			U
# M			M
# A			A
# B			B
# E			E
# K			K
# T			T
# F			F
# Y			Y
# D			T
# H			H
# W			W
# W			W
# O			O
# Q			G
# W			W
# L			L
# Q			Q
# R			R
# X			K
# B			D
# P			P
# T			T
# B			B
# G			L
# V			V
# Q			Q
# G			G
# B			S
# G			W
# V			V
# L			L
# D			D
# R			R
# L			L
# C			C
# N			N
# V			V
# I			I
# P			P
# K			C
# F			F
# W			W
# A			A
# P			P
# I			T
# H			H
# B			B
# K			K
# I			I
# W			W
# B			R
# J			J
# K			R
# K			K
# A			A
# Q			Q
# Q			Q
# A			A
# M			M
# V			V
# U			U
# G			G
# D			O
# U			U
# H			H
# V			V
# G			G
# Q			Q
# I			I
# T			T
# G			G
# F			I
